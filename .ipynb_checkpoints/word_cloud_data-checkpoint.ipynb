# %%
import pandas as pd

# %%
data = pd.read_csv("closed_caption_12_30_21_non_CO.csv")

# %%
print(data.head())
# Out:
#   data         Market Station       Date      Time Search Phrase  \
# 0  NaN  Oklahoma City    KOCO  30-Dec-21  06:15 PM          fire
# 1  NaN   Philadelphia    WPVI  30-Dec-21  06:15 PM          fire
# 2  NaN   Philadelphia    WPVI  30-Dec-21  06:15 PM          fire
# 3  NaN   Philadelphia    WPVI  30-Dec-21  06:15 PM          fire
# 4   no   Philadelphia    WPVI  30-Dec-21  06:15 PM          fire
#
#                                      Closed Captions  Hits    Demographic  \
# 0   , OF THIS FIRE AT AN AUTO WE WERE THERE AS FI...     2     Households
# 1   FIRE MARSHALL. PARADE TO HONOR PINE HILL FIRE...     4  Females 12-24
# 2   FIRE MARSHALL. PARADE TO HONOR PINE HILL FIRE...     4  Females 18-34
# 3   FIRE MARSHALL. PARADE TO HONOR PINE HILL FIRE...     4  Females 18-49
# 4   FIRE MARSHALL. PARADE TO HONOR PINE HILL FIRE...     4  Females 25-49
#
#    Minute Ratings  Quarter Hour Ratings  Minute Gains  Minute Losses
# 0           3.690                 5.677         0.016          0.011
# 1           0.417                 0.775         0.220          0.000
# 2           0.814                 1.551         0.000          0.188
# 3           1.007                 1.729         0.097          0.095
# 4           1.072                 2.000         0.124          0.121

# %%
filtered_data = data[data['data'] == 'yes']

# %%
filtered_data.head(3)
# Out:
#     data                     Market Station       Date      Time  \
# 69   yes                  Charlotte    WSOC  30-Dec-21  06:14 PM
# 101  yes  Tampa-St. Pete (Sarasota)    WFTS  30-Dec-21  06:14 PM
# 165  yes         Phoenix (Prescott)    KNXV  30-Dec-21  06:12 PM
#
#     Search Phrase                                    Closed Captions  Hits  \
# 69           fire                         CATCHING FIRE WITHOUT EVEN     1
# 101          fire   ACTUALLY PUT OUT THE FIRE APARTMENTS. THE FIR...     4
# 165          fire                          NORTH OF DENVER. THE FIRE     1
#
#        Demographic  Minute Ratings  Quarter Hour Ratings  Minute Gains  \
# 69   Females 25-49           1.575                 1.575           0.0
# 101  Females 25-49           0.274                 0.273           0.0
# 165  Females 25-49           0.519                 0.771           0.0
#
#      Minute Losses
# 69             0.0
# 101            0.0
# 165            0.0

# %%
filtered_data['Closed Captions']
# Out:
# 69                             CATCHING FIRE WITHOUT EVEN
# 101      ACTUALLY PUT OUT THE FIRE APARTMENTS. THE FIR...
# 165                             NORTH OF DENVER. THE FIRE
# 197                             >> VEHICLES CATCHING FIRE
# 295                               FIRE. STARTED THE FIRE.
#                               ...
# 3757                        FIRE, THERE WERE NO INJURIES.
# 3789     HYUNDAI ARE CAUGHT FIRE WITHOUT KIA VEHICLES ...
# 3826                            >> VEHICLES CATCHING FIRE
# 3893     CAL FIRE ALSO URGES PEOPLE TO CAL FIRE EXPLAI...
# 4093                            SPREADING LIKE WILD FIRE.
# Name: Closed Captions, Length: 67, dtype: object

# %%
filtered_data['captions'] = filtered_data['Closed Captions'].str.strip('>')
filtered_data['captions'] = filtered_data['captions'].str.strip()
# Out:
# /Users/loren/.pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/loren/.pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
filtered_data['captions'].values
# Out:
# array(['CATCHING FIRE WITHOUT EVEN',
#        'ACTUALLY PUT OUT THE FIRE APARTMENTS. THE FIRE FIRE, HOW MANY OF THE INJURED HOSPITAL AFTER A FIRE AT AN',
#        'NORTH OF DENVER. THE FIRE', '>> VEHICLES CATCHING FIRE',
#        'FIRE. STARTED THE FIRE.', 'CAL FIRE ALSO URGES PEOPLE TO',
#        'LOOKS LIKE IT’S ON FIRE', 'ONE FIRE HAS GROWN TO 1600',
#        'SPREADING LIKE WILD FIRE.',
#        'I WANT TO ASSURE YOU OUR FIRE THIS FIRE RAVAGING WHAT USED TO',
#        'FIRE BOULDER, COLORADO. FIRE CALLED THE CALWOOD FIRE MOMENTS AGO. THIS FIRE CAUSING THAT IF YOU SEE FIRE AND',
#        'FLAMES AND CAUSING THE FIRE TO', 'ON FIRE.', 'FIRE SEASON.',
#        'AFTER A FIRE BROKE OUT AT A', 'FIRE OFFICIALS ASKED PEOPLE TO',
#        'FIRE.', 'DANGEROUS FIRE CONDITIONS IN',
#        'TRACKING THOSE DANGEROUS FIRE', 'DANGEROUS FIRE CONDITIONS IN',
#        'DANGEROUS FIRE CONDITIONS IN', 'TRACKING THOSE DANGEROUS FIRE',
#        'DANGEROUS FIRE CONDITIONS IN', 'TRACKING THOSE DANGEROUS FIRE',
#        'TRACKING THOSE DANGEROUS FIRE', 'TRACKING THOSE DANGEROUS FIRE',
#        'FIRE BEHIND THEM.', 'FIRE BEHIND THEM.', 'FIRE BEHIND THEM.',
#        'FIRE BEHIND THEM.', 'FIRE BEHIND THEM.',
#        'FIRE BEHIND THEM. FIRE, INTENSITY OF THIS FIRE AND',
#        'FIRE BEHIND THEM. FIRE, INTENSITY OF THIS FIRE AND',
#        'FIRE BEHIND THEM. FIRE, INTENSITY OF THIS FIRE AND',
#        'FIRE BEHIND THEM. FIRE, INTENSITY OF THIS FIRE AND',
#        'THE FIRE SPREADING IN JUST A', 'THE FIRE SPREADING IN JUST A',
#        'BY A FIRE. AND I THINK WE’RE', 'THE FIRE SPREADING IN JUST A',
#        'FIRE HERE KICKED OFF A YEAR OF', 'THE FIRE SPREADING IN JUST A',
#        'THE FIRE SPREADING IN JUST A', 'THE FIRE SPREADING IN JUST A',
#        'THE FIRE SPREADING IN JUST A', 'THE FIRE SPREADING IN JUST A',
#        'THE FIRE SPREADING IN JUST A', 'THE FIRE CONDITIONS AND SEVERE',
#        'THE FIRE CONDITIONS AND SEVERE', 'THE FIRE CONDITIONS AND SEVERE',
#        'THE FIRE CONDITIONS AND SEVERE', 'THE FIRE CONDITIONS AND SEVERE',
#        'THE FIRE CONDITIONS AND SEVERE', 'THE FIRE CONDITIONS AND SEVERE',
#        'THE FIRE CONDITIONS AND SEVERE', 'THE FIRE CONDITIONS AND SEVERE',
#        'FIRE. SPARKING THIS FIRE. THIS FIRE BURNING DOWN HUNDREDS',
#        'THE FIRE HAS SHUT DOWN PART OF',
#        'INJURED BECAUSE OF THE FIRE AND YOU CANNOT FIGHT A FIRE WITH',
#        '>> FIRE. FIRE.', 'AS YOU CAN SEE A HORRIBLE FIRE.',
#        'OF WILDFIRES. ONE OF THE FIRE', 'OFFICIALS THINK THAT THE FIRE',
#        'FIRE, THERE WERE NO INJURIES.',
#        'HYUNDAI ARE CAUGHT FIRE WITHOUT KIA VEHICLES CATCHING FIRE',
#        '>> VEHICLES CATCHING FIRE',
#        'CAL FIRE ALSO URGES PEOPLE TO CAL FIRE EXPLAINS THE DANGER',
#        'SPREADING LIKE WILD FIRE.'], dtype=object)

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
words = " ".join(word for word in filtered_data['captions'])
stopwords = set(STOPWORDS)

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
cap_stopwords = []
for word in stopwords:
    cap_stopwords.append(word.upper())

# %%
cap_stopwords.sort()

# %%
cap_stopwords = set(cap_stopwords)

# %%
cap_stopwords
# Out:
# {'A',
#  'ABOUT',
#  'ABOVE',
#  'AFTER',
#  'AGAIN',
#  'AGAINST',
#  'ALL',
#  'ALSO',
#  'AM',
#  'AN',
#  'AND',
#  'ANY',
#  'ARE',
#  "AREN'T",
#  'AS',
#  'AT',
#  'BE',
#  'BECAUSE',
#  'BEEN',
#  'BEFORE',
#  'BEING',
#  'BELOW',
#  'BETWEEN',
#  'BOTH',
#  'BUT',
#  'BY',
#  'CAN',
#  "CAN'T",
#  'CANNOT',
#  'COM',
#  'COULD',
#  "COULDN'T",
#  'DID',
#  "DIDN'T",
#  'DO',
#  'DOES',
#  "DOESN'T",
#  'DOING',
#  "DON'T",
#  'DOWN',
#  'DURING',
#  'EACH',
#  'ELSE',
#  'EVER',
#  'FEW',
#  'FOR',
#  'FROM',
#  'FURTHER',
#  'GET',
#  'HAD',
#  "HADN'T",
#  'HAS',
#  "HASN'T",
#  'HAVE',
#  "HAVEN'T",
#  'HAVING',
#  'HE',
#  "HE'D",
#  "HE'LL",
#  "HE'S",
#  'HENCE',
#  'HER',
#  'HERE',
#  "HERE'S",
#  'HERS',
#  'HERSELF',
#  'HIM',
#  'HIMSELF',
#  'HIS',
#  'HOW',
#  "HOW'S",
#  'HOWEVER',
#  'HTTP',
#  'I',
#  "I'D",
#  "I'LL",
#  "I'M",
#  "I'VE",
#  'IF',
#  'IN',
#  'INTO',
#  'IS',
#  "ISN'T",
#  'IT',
#  "IT'S",
#  'ITS',
#  'ITSELF',
#  'JUST',
#  'K',
#  "LET'S",
#  'LIKE',
#  'ME',
#  'MORE',
#  'MOST',
#  "MUSTN'T",
#  'MY',
#  'MYSELF',
#  'NO',
#  'NOR',
#  'NOT',
#  'OF',
#  'OFF',
#  'ON',
#  'ONCE',
#  'ONLY',
#  'OR',
#  'OTHER',
#  'OTHERWISE',
#  'OUGHT',
#  'OUR',
#  'OURS',
#  'OURSELVES',
#  'OUT',
#  'OVER',
#  'OWN',
#  'R',
#  'SAME',
#  'SHALL',
#  "SHAN'T",
#  'SHE',
#  "SHE'D",
#  "SHE'LL",
#  "SHE'S",
#  'SHOULD',
#  "SHOULDN'T",
#  'SINCE',
#  'SO',
#  'SOME',
#  'SUCH',
#  'THAN',
#  'THAT',
#  "THAT'S",
#  'THE',
#  'THEIR',
#  'THEIRS',
#  'THEM',
#  'THEMSELVES',
#  'THEN',
#  'THERE',
#  "THERE'S",
#  'THEREFORE',
#  'THESE',
#  'THEY',
#  "THEY'D",
#  "THEY'LL",
#  "THEY'RE",
#  "THEY'VE",
#  'THIS',
#  'THOSE',
#  'THROUGH',
#  'TO',
#  'TOO',
#  'UNDER',
#  'UNTIL',
#  'UP',
#  'VERY',
#  'WAS',
#  "WASN'T",
#  'WE',
#  "WE'D",
#  "WE'LL",
#  "WE'RE",
#  "WE'VE",
#  'WERE',
#  "WEREN'T",
#  'WHAT',
#  "WHAT'S",
#  'WHEN',
#  "WHEN'S",
#  'WHERE',
#  "WHERE'S",
#  'WHICH',
#  'WHILE',
#  'WHO',
#  "WHO'S",
#  'WHOM',
#  'WHY',
#  "WHY'S",
#  'WITH',
#  "WON'T",
#  'WOULD',
#  "WOULDN'T",
#  'WWW',
#  'YOU',
#  "YOU'D",
#  "YOU'LL",
#  "YOU'RE",
#  "YOU'VE",
#  'YOUR',
#  'YOURS',
#  'YOURSELF',
#  'YOURSELVES'}

# %%
words = words.replace('.', '').replace(',', '').replace('’',"'")

# %%
words
# Out:
# "CATCHING FIRE WITHOUT EVEN ACTUALLY PUT OUT THE FIRE APARTMENTS THE FIRE FIRE HOW MANY OF THE INJURED HOSPITAL AFTER A FIRE AT AN NORTH OF DENVER THE FIRE >> VEHICLES CATCHING FIRE FIRE STARTED THE FIRE CAL FIRE ALSO URGES PEOPLE TO LOOKS LIKE IT'S ON FIRE ONE FIRE HAS GROWN TO 1600 SPREADING LIKE WILD FIRE I WANT TO ASSURE YOU OUR FIRE THIS FIRE RAVAGING WHAT USED TO FIRE BOULDER COLORADO FIRE CALLED THE CALWOOD FIRE MOMENTS AGO THIS FIRE CAUSING THAT IF YOU SEE FIRE AND FLAMES AND CAUSING THE FIRE TO ON FIRE FIRE SEASON AFTER A FIRE BROKE OUT AT A FIRE OFFICIALS ASKED PEOPLE TO FIRE DANGEROUS FIRE CONDITIONS IN TRACKING THOSE DANGEROUS FIRE DANGEROUS FIRE CONDITIONS IN DANGEROUS FIRE CONDITIONS IN TRACKING THOSE DANGEROUS FIRE DANGEROUS FIRE CONDITIONS IN TRACKING THOSE DANGEROUS FIRE TRACKING THOSE DANGEROUS FIRE TRACKING THOSE DANGEROUS FIRE FIRE BEHIND THEM FIRE BEHIND THEM FIRE BEHIND THEM FIRE BEHIND THEM FIRE BEHIND THEM FIRE BEHIND THEM FIRE INTENSITY OF THIS FIRE AND FIRE BEHIND THEM FIRE INTENSITY OF THIS FIRE AND FIRE BEHIND THEM FIRE INTENSITY OF THIS FIRE AND FIRE BEHIND THEM FIRE INTENSITY OF THIS FIRE AND THE FIRE SPREADING IN JUST A THE FIRE SPREADING IN JUST A BY A FIRE AND I THINK WE'RE THE FIRE SPREADING IN JUST A FIRE HERE KICKED OFF A YEAR OF THE FIRE SPREADING IN JUST A THE FIRE SPREADING IN JUST A THE FIRE SPREADING IN JUST A THE FIRE SPREADING IN JUST A THE FIRE SPREADING IN JUST A THE FIRE SPREADING IN JUST A THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE THE FIRE CONDITIONS AND SEVERE FIRE SPARKING THIS FIRE THIS FIRE BURNING DOWN HUNDREDS THE FIRE HAS SHUT DOWN PART OF INJURED BECAUSE OF THE FIRE AND YOU CANNOT FIGHT A FIRE WITH >> FIRE FIRE AS YOU CAN SEE A HORRIBLE FIRE OF WILDFIRES ONE OF THE FIRE OFFICIALS THINK THAT THE FIRE FIRE THERE WERE NO INJURIES HYUNDAI ARE CAUGHT FIRE WITHOUT KIA VEHICLES CATCHING FIRE >> VEHICLES CATCHING FIRE CAL FIRE ALSO URGES PEOPLE TO CAL FIRE EXPLAINS THE DANGER SPREADING LIKE WILD FIRE"

# %%
len(stopwords)
# Out:
# 192

# %%
len(cap_stopwords)
# Out:
# 192

# %%
len(words.split())
# Out:
# 392

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='black', colormap='Set2', collocations=False, stopwords = cap_stopwords).generate(words)

# Plot
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
clean_words = []

for word in words.split():
    if word not in cap_stopwords:
        clean_words.append(word)

# %%
clean_words
# Out:
# ['CATCHING',
#  'FIRE',
#  'WITHOUT',
#  'EVEN',
#  'ACTUALLY',
#  'PUT',
#  'FIRE',
#  'APARTMENTS',
#  'FIRE',
#  'FIRE',
#  'MANY',
#  'INJURED',
#  'HOSPITAL',
#  'FIRE',
#  'NORTH',
#  'DENVER',
#  'FIRE',
#  '>>',
#  'VEHICLES',
#  'CATCHING',
#  'FIRE',
#  'FIRE',
#  'STARTED',
#  'FIRE',
#  'CAL',
#  'FIRE',
#  'URGES',
#  'PEOPLE',
#  'LOOKS',
#  'FIRE',
#  'ONE',
#  'FIRE',
#  'GROWN',
#  '1600',
#  'SPREADING',
#  'WILD',
#  'FIRE',
#  'WANT',
#  'ASSURE',
#  'FIRE',
#  'FIRE',
#  'RAVAGING',
#  'USED',
#  'FIRE',
#  'BOULDER',
#  'COLORADO',
#  'FIRE',
#  'CALLED',
#  'CALWOOD',
#  'FIRE',
#  'MOMENTS',
#  'AGO',
#  'FIRE',
#  'CAUSING',
#  'SEE',
#  'FIRE',
#  'FLAMES',
#  'CAUSING',
#  'FIRE',
#  'FIRE',
#  'FIRE',
#  'SEASON',
#  'FIRE',
#  'BROKE',
#  'FIRE',
#  'OFFICIALS',
#  'ASKED',
#  'PEOPLE',
#  'FIRE',
#  'DANGEROUS',
#  'FIRE',
#  'CONDITIONS',
#  'TRACKING',
#  'DANGEROUS',
#  'FIRE',
#  'DANGEROUS',
#  'FIRE',
#  'CONDITIONS',
#  'DANGEROUS',
#  'FIRE',
#  'CONDITIONS',
#  'TRACKING',
#  'DANGEROUS',
#  'FIRE',
#  'DANGEROUS',
#  'FIRE',
#  'CONDITIONS',
#  'TRACKING',
#  'DANGEROUS',
#  'FIRE',
#  'TRACKING',
#  'DANGEROUS',
#  'FIRE',
#  'TRACKING',
#  'DANGEROUS',
#  'FIRE',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'INTENSITY',
#  'FIRE',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'INTENSITY',
#  'FIRE',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'INTENSITY',
#  'FIRE',
#  'FIRE',
#  'BEHIND',
#  'FIRE',
#  'INTENSITY',
#  'FIRE',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'THINK',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'KICKED',
#  'YEAR',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'SPREADING',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'CONDITIONS',
#  'SEVERE',
#  'FIRE',
#  'SPARKING',
#  'FIRE',
#  'FIRE',
#  'BURNING',
#  'HUNDREDS',
#  'FIRE',
#  'SHUT',
#  'PART',
#  'INJURED',
#  'FIRE',
#  'FIGHT',
#  'FIRE',
#  '>>',
#  'FIRE',
#  'FIRE',
#  'SEE',
#  'HORRIBLE',
#  'FIRE',
#  'WILDFIRES',
#  'ONE',
#  'FIRE',
#  'OFFICIALS',
#  'THINK',
#  'FIRE',
#  'FIRE',
#  'INJURIES',
#  'HYUNDAI',
#  'CAUGHT',
#  'FIRE',
#  'WITHOUT',
#  'KIA',
#  'VEHICLES',
#  'CATCHING',
#  'FIRE',
#  '>>',
#  'VEHICLES',
#  'CATCHING',
#  'FIRE',
#  'CAL',
#  'FIRE',
#  'URGES',
#  'PEOPLE',
#  'CAL',
#  'FIRE',
#  'EXPLAINS',
#  'DANGER',
#  'SPREADING',
#  'WILD',
#  'FIRE']

# %%
def word_freq(words):
    count = {}

    for word in words:
        if word not in count:
            count[word] = 1
        else:
            count[word] += 1
            
    return count

# %%
word_counts = word_freq(clean_words)
word_counts
# Out:
# {'CATCHING': 4,
#  'FIRE': 90,
#  'WITHOUT': 2,
#  'EVEN': 1,
#  'ACTUALLY': 1,
#  'PUT': 1,
#  'APARTMENTS': 1,
#  'MANY': 1,
#  'INJURED': 2,
#  'HOSPITAL': 1,
#  'NORTH': 1,
#  'DENVER': 1,
#  '>>': 3,
#  'VEHICLES': 3,
#  'STARTED': 1,
#  'CAL': 3,
#  'URGES': 2,
#  'PEOPLE': 3,
#  'LOOKS': 1,
#  'ONE': 2,
#  'GROWN': 1,
#  '1600': 1,
#  'SPREADING': 11,
#  'WILD': 2,
#  'WANT': 1,
#  'ASSURE': 1,
#  'RAVAGING': 1,
#  'USED': 1,
#  'BOULDER': 1,
#  'COLORADO': 1,
#  'CALLED': 1,
#  'CALWOOD': 1,
#  'MOMENTS': 1,
#  'AGO': 1,
#  'CAUSING': 2,
#  'SEE': 2,
#  'FLAMES': 1,
#  'SEASON': 1,
#  'BROKE': 1,
#  'OFFICIALS': 2,
#  'ASKED': 1,
#  'DANGEROUS': 9,
#  'CONDITIONS': 13,
#  'TRACKING': 5,
#  'BEHIND': 9,
#  'INTENSITY': 4,
#  'THINK': 2,
#  'KICKED': 1,
#  'YEAR': 1,
#  'SEVERE': 9,
#  'SPARKING': 1,
#  'BURNING': 1,
#  'HUNDREDS': 1,
#  'SHUT': 1,
#  'PART': 1,
#  'FIGHT': 1,
#  'HORRIBLE': 1,
#  'WILDFIRES': 1,
#  'INJURIES': 1,
#  'HYUNDAI': 1,
#  'CAUGHT': 1,
#  'KIA': 1,
#  'EXPLAINS': 1,
#  'DANGER': 1}

# %%
words_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Count'])

final_words_df = words_df[words_df['Count'] > 1]
final_words_df
# Out:
#           Word  Count
# 0     CATCHING      4
# 1         FIRE     90
# 2      WITHOUT      2
# 8      INJURED      2
# 12          >>      3
# 13    VEHICLES      3
# 15         CAL      3
# 16       URGES      2
# 17      PEOPLE      3
# 19         ONE      2
# 22   SPREADING     11
# 23        WILD      2
# 34     CAUSING      2
# 35         SEE      2
# 39   OFFICIALS      2
# 41   DANGEROUS      9
# 42  CONDITIONS     13
# 43    TRACKING      5
# 44      BEHIND      9
# 45   INTENSITY      4
# 46       THINK      2
# 49      SEVERE      9

# %%
# set figure size
fig, ax = plt.subplots(figsize=(12, 8))
# plot horizontal bar plot
final_words_df.sort_values(by='Count').plot.barh(x="Word", y="Count", ax=ax)
# set the title
plt.title("Most Common words in captions")

for i, v in enumerate(final_words_df['Count'].sort_values()):
    ax.text(v + 1, i - .2, str(v),
            color = 'blue', fontweight = 'bold')

plt.show()

# %%
clean_words_str = " ".join(word for word in final_words_df['Word'].values)
clean_words_str
# Out:
# 'CATCHING FIRE WITHOUT INJURED >> VEHICLES CAL URGES PEOPLE ONE SPREADING WILD CAUSING SEE OFFICIALS DANGEROUS CONDITIONS TRACKING BEHIND INTENSITY THINK SEVERE'

# %%
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', colormap='Set2', collocations=False, stopwords = cap_stopwords).generate(clean_words_str)

# Plot
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Out:
# array(['CATCHING', 'FIRE', 'WITHOUT', 'INJURED', '>>', 'VEHICLES', 'CAL',
#        'URGES', 'PEOPLE', 'ONE', 'SPREADING', 'WILD', 'CAUSING', 'SEE',
#        'OFFICIALS', 'DANGEROUS', 'CONDITIONS', 'TRACKING', 'BEHIND',
#        'INTENSITY', 'THINK', 'SEVERE'], dtype=object)

# %%
final_words_df.sort_values(by='Count')
# Out:
#           Word  Count
# 22        WILD      2
# 2      WITHOUT      2
# 8      INJURED      2
# 15       URGES      2
# 18         ONE      2
# 38   OFFICIALS      2
# 45       THINK      2
# 33     CAUSING      2
# 34         SEE      2
# 12    VEHICLES      3
# 14         CAL      3
# 16      PEOPLE      3
# 44   INTENSITY      4
# 0     CATCHING      4
# 42    TRACKING      5
# 40   DANGEROUS      9
# 43      BEHIND      9
# 48      SEVERE      9
# 21   SPREADING     11
# 41  CONDITIONS     13
# 1         FIRE     90

# %%
words_df
# Out:
# Empty DataFrame
# Columns: [Word, Frequency]
# Index: []
