# %%
file = open("clean_denver_analysis_5_7pm_fire_12_30_21.txt", mode='r', encoding='utf-8-sig')
# file.read()

# %%
text = file.read()

# %%
file.close()

# %%
text = text.replace(',', '').replace('>','').replace('.','').replace('\n','').replace('’',"'").replace('!','').replace('?','').replace('%','').replace(')','').replace('(','').replace('_','').replace(':','')
text = text.lower()

clean_text = ''
# remove numbers
for i in text:
    if not i.isdigit():
      clean_text += i
    
clean_text_list = clean_text.split(' ')
len(clean_text_list)
# Out:
# 21772

# %%
# https://en.wikipedia.org/wiki/Glossary_of_climate_change
climate_change_related_words = [
    'adaptation',
    'all-time',
    'arctic shrinkage',
    'carbon',
    'carbon dioxide',
    'carbon footprint',
    'carbon offset',
    'carbon tax',
    'celsius',
    'climate',
    'climate change',
    'climate crisis',
    'climate justice',
    'crisis',
    'degree',
    'ecosystem',
    'energy',
    'environmental',
    'extreme weather event',
    'fossil fuel',
    'glacial',
    'global',
    'global climate',
    'global cooling',
    'global warming',
    'global warming controversy',
    'global warming denial',
    'greenhouse',
    'greenhouse debt',
    'greenhouse effect',
    'greenhouse gas',
    'greenland ice sheet',
    'historic',
    'historical',
    'historical temperature record',
    'history',
    'hottest',
    'ice sheet',
    'life-threatening',
    'megadrought',
    'meteorologist',
    'meteorology',
    'mitigation',
    'natural',
    'nitrous oxide',
    'ozone',
    'planet',
    'policies',
    'policy',
    'pollution',
    'record',
    'record breaking',
    'record-setting',
    'renewable resource',
    'report',
    'reversable',
    'reverse',
    'science',
    'scientist',
    'sea ice',
    'sea level',
    'sea-level',
    'sea-level rise',
    'severe',
    'solar',
    'unprecedented',
    'warm',
    'warmest',
    'warming'
]

# %%
climate_change_related_words.sort()

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))

from wordcloud import STOPWORDS
regions = ['chicago', 'california', 'denver', 'boulder','city', 'kansas', 'area', 'indiana', 'illinois', 'colorado']
covid_related = ['omicron', 'delta', 'vaccine', 'mask', 'mandate', 'school', 'covid', 'decline']
time_related = ['tonight', "tonight's", 'now', 'saturday', 'tomorrow', 'yesterday']
names = ['erica', 'alan', 'whit', 'christian', 'russell', 'rob', 'jeff', 'mike', 'jonathan', 'jeremy']
random_words = ['pm', 'people', 'murder', 'watching', 'saying', 'go', 'one', 'thank', 'you', 'two', 'live', 'want', 'saw', 'see', 'let', 'even', 'may', 'side', 'able', 'trying', 'near', 'said', 'going', 'us', 'coming', 'reporter', '']
more_stop_words = [i.lower() for i in STOPWORDS]
final_stop_words = list(stop_words) + more_stop_words + regions + random_words + time_related + names + covid_related
final_stop_words = set(final_stop_words)
len(final_stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /Users/loren/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 286

# %%
filtered_clean_text_list = []

# remove stopwords
for word in clean_text_list:
    if word in final_stop_words:
        continue
    # don't care about numbers
    elif word.isdigit():
        continue
    # don't care about timestamps
    elif word.startswith('pm'):
        continue
    # don't care about timestamps
    elif '20211230' in word:
        continue
    # don't care about timestamps
    elif 'households' in word:
        continue
    # if history/historical/historic
    elif 'histor' in word:
        filtered_clean_text_list.append('historic')
    # if flames
    elif 'flame' in word:
        filtered_clean_text_list.append('fire')
    # remove -- from places where dates used to be
    elif '--' in word:
        filtered_clean_text_list.append(word.replace('--',''))
    else:
        filtered_clean_text_list.append(word)
        
len(filtered_clean_text_list) # 9582
# Out:
# 9582

# %%
set(filtered_clean_text_list)
# Out:
# {'',
#  'activated',
#  'bags',
#  'pick',
#  'activists',
#  'continuing',
#  'run',
#  'tree',
#  'issue',
#  'harms',
#  'barely',
#  'teenager',
#  'cooke',
#  'active',
#  'story',
#  'tape',
#  'devastated',
#  'magnitude',
#  'idea',
#  'horrific',
#  'water',
#  'geographical',
#  'fill',
#  'wyatt',
#  'vehicle',
#  'work',
#  'looked',
#  'sure',
#  'wildfires',
#  'canto',
#  'positive',
#  'region',
#  'fuelling',
#  'within',
#  'immediately',
#  'reporting',
#  'memphis',
#  'upon',
#  'related',
#  'homeowners',
#  'next',
#  'guard',
#  'half',
#  'mayors',
#  'burping',
#  'howard"',
#  'knowing',
#  'wild',
#  'speeds',
#  'lake',
#  'minimal',
#  'presence',
#  'critical',
#  'dubbed',
#  'rush',
#  'dozens',
#  'paris',
#  'perhaps',
#  'situation',
#  'hoped',
#  'difficult',
#  'officers',
#  'ef',
#  'fast-moving',
#  'fork',
#  'groups',
#  'several',
#  'nightfall',
#  'spike',
#  'hotline',
#  'possibility',
#  'hundreds',
#  'lakes',
#  'bootleg',
#  'national',
#  'continuous',
#  'expecting',
#  'foot',
#  'hailed',
#  'price',
#  'sharp',
#  'thought',
#  'creek',
#  'fallen',
#  'little',
#  'acres',
#  'change',
#  'bring',
#  'rescue',
#  'keep',
#  'clusters',
#  'zoo',
#  'suborns',
#  'density',
#  'great',
#  'begins',
#  'street',
#  'leading',
#  'app',
#  'survive',
#  'rushed',
#  'hopeless',
#  'outsideouisville',
#  'remains',
#  'fair',
#  'simply',
#  'triple',
#  'amount',
#  'operations',
#  'reports',
#  'holiday',
#  'illegal',
#  'victims',
#  'administration',
#  'routes',
#  'city',
#  'nowi',
#  'embers',
#  'watch',
#  'highway',
#  'wanted',
#  'heaviest',
#  'lessening',
#  'kess',
#  'multiple',
#  'taking',
#  'well',
#  'crashing',
#  'popping',
#  'finally',
#  'president',
#  'marshall',
#  'church',
#  'potentially',
#  'house',
#  'shaded',
#  'day',
#  'tomorrowfire',
#  'beyond',
#  'driving',
#  'kicking',
#  'caslin',
#  'march',
#  'incoming',
#  'tons',
#  'york',
#  'edge',
#  'tractor',
#  'individual',
#  '-year-olds',
#  'escaping',
#  'remember',
#  'populated',
#  'happen',
#  'catch',
#  'suspended',
#  'sparked',
#  'enough',
#  'yet',
#  'stage',
#  'common',
#  'goes',
#  'floodwaters',
#  'iburning',
#  'troublesome',
#  'mean',
#  'continues',
#  'news',
#  'treating',
#  'scorched',
#  'degrees',
#  'showed',
#  'location',
#  "homesthey're",
#  'oin',
#  'luzdelia',
#  'attack',
#  'roads',
#  'retreat',
#  'neighborhood',
#  'firing',
#  "nbc's",
#  'overrun',
#  'marshal',
#  'cherryville',
#  'camera',
#  'is',
#  'factor',
#  'boy',
#  'fewer',
#  'crossing',
#  'itlouisville',
#  'radar',
#  'presenting',
#  'terribly',
#  'ida',
#  'busy',
#  'view',
#  'inside',
#  'nothing',
#  'possibly',
#  'came',
#  'put',
#  'prepared',
#  'hospitalizations',
#  'ominous',
#  'killed',
#  'bedestroyed',
#  'actually',
#  'monitor',
#  'gulch',
#  'mid',
#  'okay',
#  'announcer',
#  'questions',
#  'deadly',
#  'customers',
#  'man',
#  'gotten',
#  'unfold',
#  'series',
#  'detecting',
#  'josie',
#  'growing',
#  'pete',
#  'shots',
#  'considered',
#  'calls',
#  'ii',
#  'much',
#  'sight',
#  'talking',
#  'mess',
#  'talked',
#  'collapsing',
#  'called',
#  'danger',
#  'war',
#  'notice',
#  'blowing',
#  'sterman',
#  'wee',
#  'update',
#  'compground',
#  'facility',
#  'need',
#  'comparison',
#  'trick',
#  'masks',
#  'happens',
#  'stop',
#  'country',
#  'pummeled',
#  'thirds',
#  'escape',
#  'top',
#  'gusty',
#  'around',
#  'confirmed',
#  'subdivision',
#  'conditions',
#  'glad',
#  'place',
#  'wildfire',
#  'feeling',
#  'actual',
#  'last',
#  'services',
#  'miami-dade',
#  'lagrone',
#  'carolina',
#  'structures',
#  'evacuated',
#  'neighbors',
#  'way',
#  'wishes',
#  'expanded',
#  'joining',
#  'kendall',
#  'prince',
#  'pandemonium',
#  'flying',
#  'death',
#  'troubles',
#  'working',
#  'hot',
#  'coursewill',
#  'minuscule',
#  'threaten',
#  'hitting',
#  'problems',
#  'miserable',
#  "year's",
#  'fills',
#  'checking',
#  'forth',
#  'rock',
#  'kits',
#  'proper',
#  'shut',
#  'pushed',
#  'careful',
#  'red',
#  'tornadoes',
#  'give',
#  'held',
#  'grow',
#  'arizona',
#  'jumps',
#  'recalled',
#  'isolated',
#  'responding',
#  'fanning',
#  'send',
#  'louisiana',
#  'low',
#  'child',
#  'least',
#  'advisories',
#  'miami',
#  'actively',
#  'inches',
#  'dylan',
#  'taken',
#  'explosion',
#  'cutting',
#  'preps',
#  'touch',
#  'high',
#  'midsouth',
#  'tankers',
#  'following',
#  'making',
#  'desperately',
#  'subway',
#  'fatalities',
#  'thankfully',
#  'ago',
#  'isor',
#  'almost',
#  'public',
#  'make',
#  'hope',
#  'preference',
#  'foced',
#  'calling',
#  'settle',
#  'milder',
#  'thursday',
#  'expect',
#  'mile-per-hour',
#  'ripping',
#  'destroyed',
#  'heavy',
#  'stay',
#  'efforts',
#  'decimated',
#  'facing',
#  'wisconsin',
#  'massive',
#  'of',
#  'soaring',
#  'right',
#  'skies',
#  'canceled',
#  'pull',
#  'job',
#  'fun',
#  'exits',
#  'couple',
#  'let‘s',
#  'othertrying',
#  'fed',
#  'speak',
#  'knocked',
#  'rule',
#  'exactly',
#  'breadth',
#  'everyone',
#  'hail',
#  'highly',
#  'thiswe',
#  'presses',
#  'action',
#  'ones',
#  'warmer',
#  'happened',
#  'evacuation',
#  'jump',
#  'nature',
#  'vividly',
#  'help',
#  'pass',
#  'avalanche',
#  'south',
#  'better',
#  'start',
#  'community',
#  'look',
#  'force',
#  'effort',
#  'vaccinations',
#  'soopers',
#  'week',
#  'georgia',
#  'fanned',
#  'wondering',
#  'wililililildfire',
#  'burn',
#  'hellish',
#  'testing',
#  'heat',
#  'largest',
#  'party',
#  'website',
#  'clearing',
#  'returning',
#  'window',
#  'heed',
#  'relax',
#  'global',
#  'connected',
#  'concern',
#  'easier',
#  'dealing',
#  'moving',
#  'all-time',
#  'thunderstorms',
#  'lines',
#  'slowly',
#  'floods',
#  'oregon',
#  'hundred',
#  'private',
#  'every',
#  'christmas',
#  'petitions',
#  'arkansas',
#  'pan',
#  'early',
#  'mother',
#  'check',
#  'torrential',
#  'car',
#  'deserve',
#  'shift',
#  'strain',
#  'mega',
#  'twice',
#  'six',
#  'changes',
#  'plus',
#  'defend',
#  'impact',
#  'officer',
#  'jumping',
#  'tahoe',
#  'extreme',
#  'plains',
#  'later',
#  'safe',
#  'west',
#  'calwood',
#  'middle',
#  'warnings',
#  '"help',
#  'mentioned',
#  'erratic',
#  'along',
#  'expected',
#  'everything',
#  'flashing',
#  'monitoring',
#  'estimate',
#  'moved',
#  'walking',
#  'relief',
#  'month',
#  "people's",
#  'wildland',
#  'anything',
#  'scrambling',
#  'waves',
#  'test',
#  'pie',
#  'turned',
#  'second',
#  'sick',
#  'devastating',
#  'decade',
#  'first',
#  'numbers',
#  'photojournalist',
#  'grace',
#  'fraser',
#  'affected',
#  'focus',
#  'diplomats',
#  'governor',
#  'snow',
#  'recent',
#  'nearly',
#  'th',
#  'appalachians',
#  'conservative',
#  'demand',
#  'january',
#  'forward',
#  'meanwhile',
#  'granby',
#  'occurred',
#  'gust',
#  'tell',
#  'bitter',
#  'shreveport',
#  'seeing',
#  'allen',
#  'times',
#  'grass',
#  'rise',
#  'major',
#  'tried',
#  'already',
#  'leaving',
#  'nationwide',
#  'youmurder',
#  'telephone',
#  'catastrophic',
#  'police',
#  'spread',
#  'iewft',
#  'seen',
#  'picture',
#  'crews',
#  'poor',
#  'houses',
#  'keeps',
#  'al',
#  'feels',
#  'engines',
#  'feel',
#  'raging',
#  'terrible',
#  'everybody',
#  'think',
#  'scale',
#  'leave',
#  'mile',
#  'intense',
#  'creating',
#  'maybe',
#  'begin',
#  'foothills',
#  'break',
#  'warmed',
#  'encounter',
#  'hurt',
#  'everywhere',
#  'united',
#  'moments',
#  'graduation',
#  'hour',
#  'emerges',
#  'never',
#  'site',
#  'weekend',
#  'neighborhoods',
#  'lost',
#  'drops',
#  'store',
#  'bahamas',
#  'immense',
#  'guessing',
#  'pines',
#  'says',
#  'front',
#  'roadway',
#  'utility',
#  "sheriff's",
#  'arctic',
#  'resulting',
#  'levels',
#  'hear',
#  'sal',
#  'essentially',
#  'delayed',
#  'western',
#  'risk',
#  'adams',
#  'ron',
#  'dc',
#  'time',
#  'playback',
#  'contributes',
#  'turning',
#  'mccaslin',
#  'northern',
#  'variant',
#  'adlibs',
#  'spreading',
#  'walk-in',
#  'goneis',
#  'tiktok',
#  'david',
#  'season',
#  'blaze',
#  'c',
#  'lawsuit',
#  'cope',
#  'youmy',
#  'play',
#  'gambling',
#  'pressure',
#  'noon',
#  'severe',
#  'body',
#  'looking',
#  'wrenching',
#  'covered',
#  'valley',
#  'rather',
#  'whit',
#  'rolled',
#  'lights',
#  'hills',
#  'clump',
#  'tv',
#  'moisture',
#  'hourexploding',
#  'bead',
#  'unrelenting',
#  'crisis',
#  'inferno',
#  'background',
#  'part',
#  'walks',
#  'ranch',
#  'dependent',
#  'afar',
#  'literally',
#  'flooding',
#  'deals',
#  'becoming',
#  'kind',
#  'sheriff',
#  'relentless',
#  'longest',
#  'system',
#  'tennessee',
#  'signs',
#  'haveare',
#  'due',
#  'safety',
#  'northwest',
#  'scary',
#  'far',
#  'americans',
#  'sky',
#  'rolling',
#  'rest',
#  'heartbreaking',
#  'contagious',
#  'blamed',
#  'nypd',
#  'talk',
#  'vantage',
#  'portland',
#  'hotblack',
#  'thewhit',
#  'highs',
#  'scare',
#  'donecountry',
#  'overnight',
#  'withwarning',
#  'took',
#  'feet',
#  'reason',
#  'destruction',
#  'cause',
#  'buried',
#  'watches',
#  'clocking',
#  'fuel',
#  'lonnie',
#  'currently',
#  'mid-south',
#  'impacting',
#  'storms',
#  'thinking',
#  'lowe',
#  'noticed',
#  'cincinnati',
#  'portions',
#  'mention',
#  'impacted',
#  'forced',
#  'arrive',
#  'collision',
#  'nation',
#  'abc',
#  'rain',
#  'rising',
#  'hero',
#  'forcing',
#  'strongest',
#  'move',
#  'vehicles',
#  'something',
#  'farm',
#  'zone',
#  'responders',
#  'monday',
#  'damage',
#  'across',
#  'vigliotti',
#  'tough',
#  'strong',
#  'celebrations',
#  'basements',
#  'stores',
#  'highways',
#  'stretch',
#  'climate',
#  'home',
#  'vista',
#  'falling',
#  'big',
#  'ofwho',
#  'overwhelming',
#  'case',
#  'alison',
#  'hill',
#  'deployed',
#  'behind',
#  'lose',
#  'guys',
#  '-year-old',
#  'dismiss',
#  'atmosphere',
#  'steadily',
#  'putting',
#  'mason',
#  'long',
#  'event',
#  'hey',
#  'someone',
#  'remnants',
#  'fathom',
#  'register',
#  'new',
#  'fillinging',
#  'watched',
#  'blinded',
#  'getting',
#  'mc',
#  'snowmobilers',
#  'air',
#  'gusting',
#  'southeast',
#  'latest',
#  'feed',
#  'element',
#  'sporadic',
#  'sites',
#  'overtime',
#  'beach',
#  'transporting',
#  'plenty',
#  'colder',
#  'wins',
#  'nearby',
#  'miles',
#  'vegas',
#  'worsening',
#  'approaching',
#  'lots',
#  'posted',
#  'alive',
#  'dealt',
#  'drive',
#  'worse',
#  "parents'",
#  'subdivisions',
#  'animal',
#  'gustsis',
#  'wide',
#  'polis',
#  'quantify',
#  'afternoon',
#  'fireslouisville',
#  'somebody',
#  'dan',
#  'superior',
#  'block',
#  'states',
#  'mosh',
#  'king',
#  'save',
#  'ordered',
#  'northeast',
#  'beginning',
#  'workers',
#  'frankly',
#  "o'clock",
#  'hurricane',
#  'manage',
#  'herestate',
#  'burning',
#  'men',
#  'kabul',
#  'known',
#  'staff',
#  'thunderstorm',
#  'die',
#  'personnel',
#  'drought',
#  'course',
#  'waiting',
#  'reaching',
#  'deep',
#  'rocky',
#  'you',
#  "mayor's",
#  'alone',
#  'drowning',
#  'snapshot',
#  'none',
#  'blistering',
#  'the',
#  'forest',
#  'spot',
#  'anyone',
#  'become',
#  'highest',
#  'service',
#  'bloag',
#  'wreck',
#  'evacuating',
#  'seem',
#  'direction',
#  'jessica',
#  'final',
#  'basically',
#  'ravage',
#  'mayor',
#  'control',
#  'lewisville',
#  'nice',
#  'acreage',
#  'evacuate',
#  'billowing',
#  'additional',
#  'lincoln',
#  'key',
#  'say',
#  'surging',
#  'find',
#  'boots',
#  'spotlight',
#  'typical',
#  'dozen',
#  'know',
#  'gusts',
#  'important',
#  'intensity',
#  'comes',
#  'suspect',
#  'fighters',
#  'areas',
#  'morning',
#  'away',
#  'unfortunately',
#  'office',
#  'ahead',
#  'atlanta',
#  'failing',
#  'nightmare',
#  'engulfed',
#  'snowfall',
#  'add',
#  'absolutely',
#  'downing',
#  'marking',
#  'curious',
#  'classes',
#  'pre-evacuation',
#  'authorities',
#  'closer',
#  'nelson',
#  'four',
#  'bringing',
#  'kids',
#  'biggest',
#  'life',
#  'in-',
#  'foundations',
#  'suburbs',
#  'millenia',
#  'pushing',
#  'birmingham',
#  'safer',
#  'whole',
#  'shortage',
#  'sweeping',
#  'scene',
#  'broomfield',
#  'exploding',
#  'tests',
#  'tens',
#  'knocking',
#  'wjlacom',
#  'ravaging',
#  'threatening',
#  'driver',
#  'glow',
#  'victim',
#  'wrath',
#  'surprising',
#  'adventist',
#  'towards',
#  'come',
#  'outbreak',
#  'oh',
#  'plate',
#  'causing',
#  'hotel',
#  'yards',
#  'officials',
#  'switch',
#  'five',
#  'family',
#  'years',
#  'including',
#  'per',
#  'obviously',
#  'flash',
#  'resident',
#  'arriving',
#  'real',
#  'ending',
#  'today',
#  'record',
#  'oxygen',
#  'backward',
#  'structural',
#  'video',
#  'outside',
#  'surprised',
#  'significantly',
#  'calm',
#  'telling',
#  'programming',
#  'igniting',
#  'listen',
#  'evacuations',
#  'east',
#  'god',
#  'blanketing',
#  'spoke',
#  'easing',
#  'eric',
#  'restaurants',
#  'drainage',
#  'bunch',
#  'alerts',
#  'grateful',
#  'months',
#  'heirlooms',
#  'sunshine',
#  'search',
#  'management',
#  'wrapping',
#  'oemcom',
#  'attorneys',
#  'extremely',
#  'precipitation',
#  'hard',
#  'shattering',
#  'backed',
#  'airport',
#  'fort',
#  'matter',
#  'andrews',
#  'twenty',
#  'quarter',
#  'department',
#  'decided',
#  'nowrapidly',
#  'malibu',
#  'share',
#  'battle',
#  'toughest',
#  'category',
#  'open',
#  'families',
#  'nashville',
#  'bill',
#  'struck',
#  'yeah',
#  'entire',
#  ...}

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')

# back to text
filtered_clean_text = " ".join(i for i in filtered_clean_text_list)

# tokenize text
tokenized_text = word_tokenize(filtered_clean_text)
# Out:
# [nltk_data] Downloading package punkt to /Users/loren/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_text)
print(fdist)
# Out:
# <FreqDist with 1605 samples and 9808 outcomes>

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
#Lexicon Normalization
#performing stemming and Lemmatization

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()

lemma_list = []
for word, tag in nltk.pos_tag(filtered_clean_text_list):
    wntag = tag[0].lower()
    wntag = wntag if wntag in ['a', 'r', 'n', 'v'] else None
    if not wntag:
        lemma = word
    else:
        lemma = lem.lemmatize(word, pos=wntag)
    lemma_list.append(lemma)
len(lemma_list)
# Out:
# [nltk_data] Downloading package wordnet to /Users/loren/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/loren/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/loren/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# 9764

# %%
lfdist = FreqDist(lemma_list)
print(fdist)


lfdist.plot(30,cumulative=False)
plt.show()
# Out:
# <FreqDist with 1605 samples and 9808 outcomes>

# %%
lfdist
# Out:
# FreqDist({'fire': 334, 'wind': 151, 'colorado': 148, 'hour': 129, 'across': 107, 'condition': 104, 'home': 96, 'weather': 93, 'bring': 83, 'smoke': 80, ...})

# %%
def word_freq(words, stopwords):
    count = {}

    for word in words:
        if word not in count:
            if not word.startswith('pm'):
                if not '20211230' in word:
                    if not 'households' in word:
                        count[word] = 1
        else:
            count[word] += 1
    return count

word_counts = word_freq(filtered_clean_text_list, final_stop_words)

# %%
# Out:
# 1

# %%
# clean up

filtered_word_counts = {k:v for (k,v) in word_counts.items() if v > 5 }
filtered_word_counts.keys()
# Out:
# dict_keys(['neighborhood', 'seen', 'expect', 'risk', 'wildfire', 'home', 'looking', '--', 'homes', 'far', 'fire', 'burn', 'colorado', 'historic', 'last', 'year', 'structures', 'lost', 'size', 'fires', 'acres', 'across', 'superior', 'anything', 'know', 'well', 'north', 'really', 'south', 'images', 'seeing', 'right', 'several', 'hours', 'time', 'running', 'happening', 'behind', 'distance', 'move', 'hundreds', 'burned', 'earlier', 'wind', 'strong', 'way', 'traffic', 'moving', 'getting', 'think', 'good', 'make', 'conditions', 'emergency', 'call', 'least', 'hospital', 'evacuated', 'close', 'smoke', 'county', 'winds', 'lot', 'weather', 'point', 'around', 'many', 'situation', 'much', 'damage', 'say', 'take', 'look', 'continue', 'crews', 'left', 'storm', 'snow', 'come', 'afternoon', 'season', 'sky', 'begin', 'hour', 'ago', 'start', 'heat', 'news', 'evening', 'couple', 'big', 'air', 'thick', 'part', 'miles', 'east', 'plains', 'little', 'advisories', 'winter', 'still', 'foothills', 'gusts', 'next', 'strongest', 'west', 'driving', 'senior', 'got', 'different', 'subdivision', 'event', 'burning', 'meteorologist', 'today', 'per', 'hurricane', "year's", 'record', 'rain', 'never', 'national', 'new', 'victims', 'vaccine', 'spreading', 'busy', 'evacuations', 'magnitude', 'threat', 'absolutely', 'residents', 'watch', 'surprised', 'told', 'help', 'wildfires', 'mountain', 'communities', 'something', 'minutes', 'yeah', 'entire', 'tree', 'night', 'governor', 'destroyed', 'bring', 'safety', 'remember', 'towards', 'thousands', 'first', 'responders', 'families', 'throughout', 'done', 'state', 'joining', 'morning', 'grass', 'highway', 'taken', 'louisville', 'town', 'sheriff', 'day', 'expected', 'retreat', 'foot', 'overnight', 'matter', 'evacuate', 'everyone', 'high', 'injuries', 'finally', 'element', 'hotel', 'forcing', 'fast-moving', 'six', 'actively', 'possible', 'power', 'lines', 'major', 'country', 'severe', 'nashville', 'concern', "abc's", 'marciano', 'tracking', 'dangerous', 'turned', 'wave', 'flip', 'switch', 'mentioned', 'watches', 'posted', 'low', 'emerges', 'mid', 'icing', 'lincoln', 'zmoesnow', 'presses', 'detroit', 'haved', 'tornadoes', 'wee', 'expanded', 'cities', 'shreveport', 'birmingham', 'atlanta', 'holiday', 'impact', 'covid', 'breaking', 'cases', 'knocking', 'highways', 'shut', 'millions', 'facing', 'slow', 'dumping', 'torrential', 'floodwaters', 'inundating', 'compground', 'malibu', 'dawn', 'okay', 'respond', 'earns', 'racing', 'rescue', 'pets', 'brought', 'crashing', 'onto', 'pacific', 'coast', 'bringing', 'utility', 'shutting', 'roadway', 'raining', 'record-setting', 'dry', 'add', 'perfect', 'supposed', 'snowing', 'almost', 'forced', 'lynn', 'joe', 'reports', 'texas', 'teenager', 'considered', 'armed', 'america', 'graduation', 'story', 'thanks', 'thursday', 'johnson', 'david', 'life-threatening', 'declaring', 'short', 'notice', 'drivers', 'blinded', 'blowing', 'roads', 'powerful', 'downing', 'igniting', 'rushed', 'customers', 'stores', 'suddenly', 'held', 'exits', 'outside', 'days', 'turn', 'fillinging', 'lake', 'deep', 'climate', 'other2021-12-30', 'mid-south', 'heavy', 'weeks', 'expansive', 'midsouth', 'slow-moving', 'campground', "abc's2021-12-30", 'series', 'of2021-12-30'])

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='black', colormap='Set2', collocations=False, stopwords = stopwords).generate_from_frequencies(word_counts)

# Plot
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import pandas as pd
words_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Count'])
# Out:
#              Word  Count
# 0        watching      7
# 1     immediately      2
# 3          saying      7
# 5             god      3
# 6              go     14
# ...           ...    ...
# 1611   campground      7
# 1612         heed      2
# 1613      warning      2
# 1614       series     14
# 1615      filling      4
#
# [825 rows x 2 columns]

# %%
final_words_df = words_df[words_df['Count'] > 5]
final_words_df
# Out:
#               Word  Count
# 0         watching      7
# 3           saying      7
# 6               go     14
# 7     neighborhood      6
# 8             seen     19
# ...            ...    ...
# 1603         weeks      8
# 1604     expansive      8
# 1610    slowmoving      7
# 1611    campground      7
# 1614        series     14
#
# [341 rows x 2 columns]

# %%
# set figure size
fig, ax = plt.subplots(figsize=(12, 8))
# plot horizontal bar plot
final_words_df.sort_values(by='Count').plot.barh(x="Word", y="Count", ax=ax)
# set the title
plt.title("Most Common words in captions")

for i, v in enumerate(final_words_df['Count'].sort_values()):
    ax.text(v + 1, i - .2, str(v),
            color = 'blue', fontweight = 'bold')

plt.show()

# %%
clean_words_str = " ".join(word for word in final_words_df['Word'].values)
clean_words_str
# Out:
# 'CATCHING FIRE WITHOUT INJURED VEHICLES ONE SPREADING CAUSING SEE OFFICIALS PEOPLE DANGEROUS CONDITIONS THINK CAL'

# %%
final_words_df.sort_values(by='Count',  ascending=False)
# Out:
#            Word  Count
# 33         fire    195
# 40     colorado    148
# 228       winds    125
# 53       across    107
# 169  conditions    104
# ..          ...    ...
# 909        team      2
# 906       comes      2
# 903        real      2
# 902       tough      2
# 971      topple      2
#
# [825 rows x 2 columns]
